# %% [markdown]
# <a href="https://colab.research.google.com/github/Pear-PL/Project-1_Coding/blob/main/Calculate_PriceGasoline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Diesel = 29.94
G95 = 40.15
G91 = 39.88
E20 = 39.04
E85 = 32.34
Bensin = 47.56

A = Diesel
B = G95
C = G91
D = E20
E = E85
F = Bensin

Hybrid = 23
Gas = 15

H = Hybrid
G = Gas

distance = int(input("ระยะทางที่ใช้ในการเดินทางเป็นกิโลเมตร(ประมาณ)"))
print(" H = Hybrid \n G = Gas")
Engine = input("ประเภทของเครื่องยนต์ที่ใช้(G,H)")
print(" A = Diesel \n B = G95 \n C = G91 \n D = E20 \n E = E85 \n F = Bensin")
Gasoline = input("ใช้น้ำมันชนิดใด(A-F)")

def Price_HybridDiesel (distance , Diesel , Hybrid) :
  Price_HybridDiesel = distance / Hybrid * Diesel
def Price_Hybrid (distance , Diesel , Gas) :
  Price_GasDiesel = distance / Gas * Diesel

def Price_Gas (distance , G95 , Gas) :
  Price_GasG95 = distance / Gas * G95
def Price_Diesel (distance , G95 , Hybrid) :
  Price_HybridG95l = distance / Hybrid * G95

def Price_G95 (distance , G91 , Hybrid) :
  Price_HybridG91 = distance / Hybrid * G91
def Price_Gas_G91(distance , G91 , Gas) :
  Price_GasG91 = distance / Gas * G91

def Price_G91 (distance , E20 , Hybrid) :
  Price_HybridE20 = distance / Hybrid * E20
def Price_E20 (distance , E20 , Gas) :
  Price_GasE20 = distance / Gas * E20

def Price_E85 (distance , E85 , Hybrid) :
  Price_HybridE85 = distance / Hybrid * E85
def Price_E85_Gas(distance , E85 , Gas) :
  Price_GasE85 = distance / Gas * E85

def Price_Bensin (distance , Bensin , Hybrid) :
  Price_HybridBensin = distance / Hybrid * Bensin
  print("Price of Bensin is ", '%.2f' %Price_Bensin)
def Price_Bensin_Gas(distance , Bensin , Gas) :
  Price_GasBensin = distance / Gas * Bensin
  print("Price of Bensin is ", '%.2f' %Price_Bensin)

if Engine == "H" and Gasoline == "A" :
  Price_HybridDiesel = distance / Hybrid * Diesel
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_HybridDiesel , "บาท")
elif Engine == "G" and Gasoline == "A" :
  Price_GasDiesel = distance / Gas * Diesel
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_GasDiesel ,  "บาท")

if Engine == "H" and Gasoline == "B" :
  Price_HybridG95 = distance / Hybrid * G95
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_HybridG95 , "บาท")
elif Engine == "G" and Gasoline == "B" :
  Price_GasG95 = distance / Gas * G95
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_GasG95 , "บาท")

if Engine == "H" and Gasoline == "C" :
  Price_HybridG91 = distance / Hybrid * G91
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_HybridG91 , "บาท")
elif Engine == "G" and Gasoline == "C" :
  Price_GasG91 = distance / Gas * G91
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_GasG91 , "บาท")

if Engine == "H" and Gasoline == "D" :
  Price_HybridE20 = distance / Hybrid * E20
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_HybridE20 , "บาท")
elif Engine == "G" and Gasoline == "D" :
  Price_GasE20 = distance / Gas * E20
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_GasE20 , "บาท")

if Engine == "H" and Gasoline == "E" :
  Price_HybridE85 = distance / Hybrid * E85
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_HybridE85 , "บาท")
elif Engine == "G" and Gasoline == "E" :
  Price_GasE85 = distance / Gas * E85
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_GasE85 , "บาท")

if Engine == "H" and Gasoline == "F" :
  Price_HybridBensin = distance / Hybrid * Bensin
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_HybridBensin , "บาท")
elif Engine == "G" and Gasoline == "F" :
  Price_GasBensin = distance / Gas * Bensin
  print("ราคน้ำมันที่ควรเติมประมาณ", '%.2f' %Price_GasBensin , "บาท")
